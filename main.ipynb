# %%
# !pip install python-fasthtml
# Out:
# Collecting python-fasthtml
#   Obtaining dependency information for python-fasthtml from https://files.pythonhosted.org/packages/1d/3e/ff185ef5d4006d633b1696c7b291706e413739afd37ac2edd4cb746d3839/python_fasthtml-0.2.4-py3-none-any.whl.metadata
#   Downloading python_fasthtml-0.2.4-py3-none-any.whl.metadata (4.9 kB)
# Collecting fastcore>=1.6.3 (from python-fasthtml)
#   Obtaining dependency information for fastcore>=1.6.3 from https://files.pythonhosted.org/packages/2f/1a/58e9a2e8e6ecd4add1e8f74d24b38adfb0455e53d92e222c94bc6e183530/fastcore-1.6.3-py3-none-any.whl.metadata
#   Downloading fastcore-1.6.3-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: python-dateutil in c:\users\wiggles\miniconda3\lib\site-packages (from python-fasthtml) (2.8.2)
# Collecting starlette>0.33 (from python-fasthtml)
#   Obtaining dependency information for starlette>0.33 from https://files.pythonhosted.org/packages/c1/60/d976da9998e4f4a99e297cda09d61ce305919ea94cbeeb476dba4fece098/starlette-0.38.2-py3-none-any.whl.metadata
#   Downloading starlette-0.38.2-py3-none-any.whl.metadata (5.9 kB)
# Collecting oauthlib (from python-fasthtml)
#   Obtaining dependency information for oauthlib from https://files.pythonhosted.org/packages/7e/80/cab10959dc1faead58dc8384a781dfbf93cb4d33d50988f7a69f1b7c9bbe/oauthlib-3.2.2-py3-none-any.whl.metadata
#   Downloading oauthlib-3.2.2-py3-none-any.whl.metadata (7.5 kB)
# Collecting itsdangerous (from python-fasthtml)
#   Obtaining dependency information for itsdangerous from https://files.pythonhosted.org/packages/04/96/92447566d16df59b2a776c0fb82dbc4d9e07cd95062562af01e408583fc4/itsdangerous-2.2.0-py3-none-any.whl.metadata
#   Downloading itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting uvicorn[standard]>=0.30 (from python-fasthtml)
#   Obtaining dependency information for uvicorn[standard]>=0.30 from https://files.pythonhosted.org/packages/67/d8/1bcb5e6508d14c6c9912cd964b286f04392298ffb3e4218f4a1292d64e76/uvicorn-0.30.5-py3-none-any.whl.metadata
#   Downloading uvicorn-0.30.5-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: httpx in c:\users\wiggles\miniconda3\lib\site-packages (from python-fasthtml) (0.23.3)
# Collecting fastlite>=0.0.6 (from python-fasthtml)
#   Obtaining dependency information for fastlite>=0.0.6 from https://files.pythonhosted.org/packages/49/56/ded38dee45c4651c5b6420994c6ff51026848059f1e66d85136d1c3ce4f4/fastlite-0.0.7-py3-none-any.whl.metadata
#   Downloading fastlite-0.0.7-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: python-multipart in c:\users\wiggles\miniconda3\lib\site-packages (from python-fasthtml) (0.0.5)
# Requirement already satisfied: beautifulsoup4 in c:\users\wiggles\miniconda3\lib\site-packages (from python-fasthtml) (4.12.2)
# Requirement already satisfied: packaging in c:\users\wiggles\miniconda3\lib\site-packages (from fastcore>=1.6.3->python-fasthtml) (22.0)
# Collecting sqlite-minutils (from fastlite>=0.0.6->python-fasthtml)
#   Obtaining dependency information for sqlite-minutils from https://files.pythonhosted.org/packages/dc/33/c46f19963b9f39a642f18dab681b575d0faf1620860c85723ed9c4fc2c2b/sqlite_minutils-3.36.0.post4-py3-none-any.whl.metadata
#   Downloading sqlite_minutils-3.36.0.post4-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: anyio<5,>=3.4.0 in c:\users\wiggles\miniconda3\lib\site-packages (from starlette>0.33->python-fasthtml) (3.6.2)
# Requirement already satisfied: click>=7.0 in c:\users\wiggles\miniconda3\lib\site-packages (from uvicorn[standard]>=0.30->python-fasthtml) (7.1.2)
# Requirement already satisfied: h11>=0.8 in c:\users\wiggles\miniconda3\lib\site-packages (from uvicorn[standard]>=0.30->python-fasthtml) (0.14.0)
# Requirement already satisfied: typing-extensions>=4.0 in c:\users\wiggles\miniconda3\lib\site-packages (from uvicorn[standard]>=0.30->python-fasthtml) (4.4.0)
# Requirement already satisfied: colorama>=0.4 in c:\users\wiggles\miniconda3\lib\site-packages (from uvicorn[standard]>=0.30->python-fasthtml) (0.4.5)
# Collecting httptools>=0.5.0 (from uvicorn[standard]>=0.30->python-fasthtml)
#   Obtaining dependency information for httptools>=0.5.0 from https://files.pythonhosted.org/packages/1e/fc/8a26c2adcd3f141e4729897633f03832b71ebea6f4c31cce67a92ded1961/httptools-0.6.1-cp310-cp310-win_amd64.whl.metadata
#   Downloading httptools-0.6.1-cp310-cp310-win_amd64.whl.metadata (3.7 kB)
# Collecting python-dotenv>=0.13 (from uvicorn[standard]>=0.30->python-fasthtml)
#   Obtaining dependency information for python-dotenv>=0.13 from https://files.pythonhosted.org/packages/6a/3e/b68c118422ec867fa7ab88444e1274aa40681c606d59ac27de5a5588f082/python_dotenv-1.0.1-py3-none-any.whl.metadata
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\wiggles\miniconda3\lib\site-packages (from uvicorn[standard]>=0.30->python-fasthtml) (6.0)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.30->python-fasthtml)
#   Obtaining dependency information for watchfiles>=0.13 from https://files.pythonhosted.org/packages/f8/79/9d7e16e805c721d5e5a3b1d1a3e798cc9b1282b799d7058a70ab506dc970/watchfiles-0.22.0-cp310-none-win_amd64.whl.metadata
#   Downloading watchfiles-0.22.0-cp310-none-win_amd64.whl.metadata (5.0 kB)
# Requirement already satisfied: websockets>=10.4 in c:\users\wiggles\miniconda3\lib\site-packages (from uvicorn[standard]>=0.30->python-fasthtml) (10.4)
# Requirement already satisfied: soupsieve>1.2 in c:\users\wiggles\miniconda3\lib\site-packages (from beautifulsoup4->python-fasthtml) (2.4.1)
# Requirement already satisfied: certifi in c:\users\wiggles\miniconda3\lib\site-packages (from httpx->python-fasthtml) (2022.12.7)
# Requirement already satisfied: httpcore<0.17.0,>=0.15.0 in c:\users\wiggles\miniconda3\lib\site-packages (from httpx->python-fasthtml) (0.16.3)
# Requirement already satisfied: rfc3986[idna2008]<2,>=1.3 in c:\users\wiggles\miniconda3\lib\site-packages (from httpx->python-fasthtml) (1.5.0)
# Requirement already satisfied: sniffio in c:\users\wiggles\miniconda3\lib\site-packages (from httpx->python-fasthtml) (1.3.0)
# Requirement already satisfied: six>=1.5 in c:\users\wiggles\miniconda3\lib\site-packages (from python-dateutil->python-fasthtml) (1.16.0)
# Requirement already satisfied: idna>=2.8 in c:\users\wiggles\miniconda3\lib\site-packages (from anyio<5,>=3.4.0->starlette>0.33->python-fasthtml) (3.4)
# Downloading python_fasthtml-0.2.4-py3-none-any.whl (36 kB)
# Downloading fastcore-1.6.3-py3-none-any.whl (76 kB)
#    ---------------------------------------- 0.0/76.3 kB ? eta -:--:--
#    ---------------------------------------- 76.3/76.3 kB 4.1 MB/s eta 0:00:00
# Downloading fastlite-0.0.7-py3-none-any.whl (14 kB)
# Downloading starlette-0.38.2-py3-none-any.whl (72 kB)
#    ---------------------------------------- 0.0/72.0 kB ? eta -:--:--
#    ---------------------------------------- 72.0/72.0 kB 1.9 MB/s eta 0:00:00
# Downloading itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Using cached oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Downloading httptools-0.6.1-cp310-cp310-win_amd64.whl (58 kB)
#    ---------------------------------------- 0.0/58.2 kB ? eta -:--:--
#    ---------------------------------------- 58.2/58.2 kB ? eta 0:00:00
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading watchfiles-0.22.0-cp310-none-win_amd64.whl (282 kB)
#    ---------------------------------------- 0.0/282.1 kB ? eta -:--:--
#    ---------- ----------------------------- 71.7/282.1 kB 2.0 MB/s eta 0:00:01
#    ------------------------ --------------- 174.1/282.1 kB 2.1 MB/s eta 0:00:01
#    ----------------------------- ---------- 204.8/282.1 kB 1.8 MB/s eta 0:00:01
#    ---------------------------------------- 282.1/282.1 kB 1.6 MB/s eta 0:00:00
# Downloading sqlite_minutils-3.36.0.post4-py3-none-any.whl (46 kB)
#    ---------------------------------------- 0.0/46.4 kB ? eta -:--:--
#    -------- ------------------------------- 10.2/46.4 kB ? eta -:--:--
#    ---------------------------------------- 46.4/46.4 kB 769.3 kB/s eta 0:00:00
# Downloading uvicorn-0.30.5-py3-none-any.whl (62 kB)
#    ---------------------------------------- 0.0/62.8 kB ? eta -:--:--
#    ------------------- -------------------- 30.7/62.8 kB 1.4 MB/s eta 0:00:01
#    ---------------------------------------- 62.8/62.8 kB 847.8 kB/s eta 0:00:00
# Installing collected packages: uvicorn, python-dotenv, oauthlib, itsdangerous, httptools, fastcore, watchfiles, starlette, sqlite-minutils, fastlite, python-fasthtml
#   Attempting uninstall: uvicorn
#     Found existing installation: uvicorn 0.20.0
#     Uninstalling uvicorn-0.20.0:
#       Successfully uninstalled uvicorn-0.20.0
#   Attempting uninstall: fastcore
#     Found existing installation: fastcore 1.5.29
#     Uninstalling fastcore-1.5.29:
#       Successfully uninstalled fastcore-1.5.29
#   Attempting uninstall: starlette
#     Found existing installation: starlette 0.22.0
#     Uninstalling starlette-0.22.0:
#       Successfully uninstalled starlette-0.22.0
# Successfully installed fastcore-1.6.3 fastlite-0.0.7 httptools-0.6.1 itsdangerous-2.2.0 oauthlib-3.2.2 python-dotenv-1.0.1 python-fasthtml-0.2.4 sqlite-minutils-3.36.0.post4 starlette-0.38.2 uvicorn-0.30.5 watchfiles-0.22.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# fastai 2.7.12 requires fastcore<1.6,>=1.5.29, but you have fastcore 1.6.3 which is incompatible.
# fastapi 0.89.1 requires starlette==0.22.0, but you have starlette 0.38.2 which is incompatible.
#
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from fasthtml.common import *

app,rt = fast_app()

@rt('/')
def get(): return Div(P('Hello World!'), hx_get="/change")

serve()
